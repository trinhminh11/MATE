# %%
import torch.nn as nn
from tqdm.notebook import tqdm_notebook as tqdm
# from tqdm import tqdm
import gym_agent as ga
from hitmac.coordinator_gpt import Ours

# %%
total_timesteps = 200000
max_episode_steps = 500
chkpt_dir = "checkpoints/LunarLander-v2/DQN"

env_id = 'LunarLander-v3'

# %% [markdown]
# # DQN

# %%
class DeepQNetwork(nn.Module):
    def __init__(self, n_inp: int, n_out: int, features: list[int] = [64, 64]):
        super().__init__()

        layers = [n_inp] + features + [n_out]

        self.net = nn.Sequential()

        for i in range(len(layers)-1):
            self.net.append(nn.Linear(layers[i], layers[i+1]))

            if i < len(layers)-2:
                self.net.append(nn.ReLU())

    def forward(self, X):
        print(f"X shape: {X.shape}")
        return self.net(X)

# %%
def net_factory():
    return DeepQNetwork(
        n_inp=8,
        n_out=4,
        features=[256, 256]
    )

# %%
policy = ga.core.TargetPolicy(
    net_factory_func=net_factory,
    lr = 1e-3
)

# %%
agent = ga.core.DQN(
    policy=policy,
    env_factory_fn=ga.make,
    env_kwargs={"id": env_id, "max_episode_steps": max_episode_steps},
    eps_decay_steps=100000,
)

# %%
agent.fit(total_timesteps=200000, save_best=True, save_dir=chkpt_dir, progress_bar=tqdm)
# Out:
#   0%|          | 0/200000 [00:00<?, ?it/s]
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([1, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([1, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([1, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([1, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([1, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([1, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([1, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([1, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([1, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([1, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([1, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# X shape: torch.Size([64, 8])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 agent.fit(total_timesteps=200000, save_best=True, save_dir=chkpt_dir, progress_bar=tqdm)
#
# File ~/Documents/Code/MATE_minhtrinh/gym_agent/core/agent_base.py:473, in AgentBase.fit(self, n_games, total_timesteps, deterministic, reset_timesteps, save_best, save_every, save_last, save_dir, progress_bar, callbacks)
#     471 counter += 1
#     472 self.reset()
# --> 473 timesteps, episodes = self.collect_buffer(deterministic, callbacks)
#     475 self.timesteps += timesteps
#     476 self.episodes += episodes
#
# File ~/Documents/Code/MATE_minhtrinh/gym_agent/core/agent_base.py:734, in OffPolicyAgent.collect_buffer(self, deterministic, callbacks)
#     732 if len(self.memory) >= self.batch_size: # if collect enough data, start learning
#     733     callbacks.on_learn_begin()
# --> 734     self.learn()
#     735     callbacks.on_learn_end()
#     737 # TODO: this is not an episode, so the callbacks should be different
#
# File ~/Documents/Code/MATE_minhtrinh/gym_agent/core/algos/off_policy/dqn.py:139, in DQN.learn(self)
#     137 self.policy.zero_grad()
#     138 loss.backward()
# --> 139 self.policy.optimizers_step()
#     140 self.policy.lr_schedulers_step()
#     142 # Update the target network
#
# File ~/Documents/Code/MATE_minhtrinh/gym_agent/core/polices.py:43, in BasePolicy.optimizers_step(self)
#      41 def optimizers_step(self):
#      42     for optimizer in self.optimizers.values():
# ---> 43         optimizer.step()
#
# File ~/miniconda3/envs/rl/lib/python3.12/site-packages/torch/optim/optimizer.py:516, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     511         else:
#     512             raise RuntimeError(
#     513                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     514             )
# --> 516 out = func(*args, **kwargs)
#     517 self._optimizer_step_code()
#     519 # call optimizer step post hooks
#
# File ~/miniconda3/envs/rl/lib/python3.12/site-packages/torch/optim/optimizer.py:81, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      79     torch.set_grad_enabled(self.defaults["differentiable"])
#      80     torch._dynamo.graph_break()
# ---> 81     ret = func(*args, **kwargs)
#      82 finally:
#      83     torch._dynamo.graph_break()
#
# File ~/miniconda3/envs/rl/lib/python3.12/site-packages/torch/optim/adam.py:247, in Adam.step(self, closure)
#     235     beta1, beta2 = group["betas"]
#     237     has_complex = self._init_group(
#     238         group,
#     239         params_with_grad,
#    (...)    244         state_steps,
#     245     )
# --> 247     adam(
#     248         params_with_grad,
#     249         grads,
#     250         exp_avgs,
#     251         exp_avg_sqs,
#     252         max_exp_avg_sqs,
#     253         state_steps,
#     254         amsgrad=group["amsgrad"],
#     255         has_complex=has_complex,
#     256         beta1=beta1,
#     257         beta2=beta2,
#     258         lr=group["lr"],
#     259         weight_decay=group["weight_decay"],
#     260         eps=group["eps"],
#     261         maximize=group["maximize"],
#     262         foreach=group["foreach"],
#     263         capturable=group["capturable"],
#     264         differentiable=group["differentiable"],
#     265         fused=group["fused"],
#     266         grad_scale=getattr(self, "grad_scale", None),
#     267         found_inf=getattr(self, "found_inf", None),
#     268         decoupled_weight_decay=group["decoupled_weight_decay"],
#     269     )
#     271 return loss
#
# File ~/miniconda3/envs/rl/lib/python3.12/site-packages/torch/optim/optimizer.py:149, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     147     return disabled_func(*args, **kwargs)
#     148 else:
# --> 149     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/rl/lib/python3.12/site-packages/torch/optim/adam.py:949, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     946 else:
#     947     func = _single_tensor_adam
# --> 949 func(
#     950     params,
#     951     grads,
#     952     exp_avgs,
#     953     exp_avg_sqs,
#     954     max_exp_avg_sqs,
#     955     state_steps,
#     956     amsgrad=amsgrad,
#     957     has_complex=has_complex,
#     958     beta1=beta1,
#     959     beta2=beta2,
#     960     lr=lr,
#     961     weight_decay=weight_decay,
#     962     eps=eps,
#     963     maximize=maximize,
#     964     capturable=capturable,
#     965     differentiable=differentiable,
#     966     grad_scale=grad_scale,
#     967     found_inf=found_inf,
#     968     decoupled_weight_decay=decoupled_weight_decay,
#     969 )
#
# File ~/miniconda3/envs/rl/lib/python3.12/site-packages/torch/optim/adam.py:533, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     531         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     532     else:
# --> 533         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     535     param.addcdiv_(exp_avg, denom, value=-step_size)
#     537 # Lastly, switch back to complex view
#
# KeyboardInterrupt:

# %%
agent.load(chkpt_dir, "best")

# %%
agent.play(jupyter=True)

# %%
agent.plot_scores(rolling_window=100)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_rolling_stats(scores, window):
    """
    Plot rolling min, mean, and max of a list of scores,
    with a shaded region between min and max.

    Parameters:
    - scores: list of numeric values
    - window: int, rolling window size
    """
    if not scores:
        raise ValueError("Scores list cannot be empty.")
    if window < 1:
        raise ValueError("Window size must be at least 1.")

    # Create pandas Series
    s = pd.Series(scores)

    # Compute rolling statistics
    rolling_max = s.rolling(window).max()
    rolling_mean = s.rolling(window).mean()
    rolling_min = s.rolling(window).min()

    # Plot
    plt.figure(figsize=(10, 6))

    # Original scores
    plt.plot(s, label="Original Scores", color="gray", alpha=0.5)

    # Shaded region between rolling min and max
    plt.fill_between(s.index, rolling_min, rolling_max,
                     color="skyblue", alpha=0.3, label="Min–Max Range")

    # Mean line
    plt.plot(rolling_mean, label=f"Rolling Mean (window={window})", color="blue", linewidth=2)

    plt.title("Rolling Statistics of Scores")
    plt.xlabel("Index")
    plt.ylabel("Score")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
scores = [10, 12, 15, 20, 18, 22, 19, 25, 30, 28, 26, 24]
plot_rolling_stats(scores, window=3)

# %% [markdown]
# # A2C

# %%
class Feature_Extractor(nn.Module): # just a FL layer
    def __init__(self, n_inp: int, features: list[int] = [256, 256]):
        super().__init__()

        layers = [n_inp] + features

        self.net = nn.Sequential()

        for i in range(len(layers)-1):
            self.net.append(nn.Linear(layers[i], layers[i+1]))
            self.net.append(nn.ReLU())

    def forward(self, X):
        return self.net(X)

# %%
def feature_extractor_factory():
    return Feature_Extractor(
        n_inp=8,
        features=[256, 256]
    )

def actor_factory():
    net = nn.Sequential(
        Feature_Extractor(n_inp=8, features=[256, 256]),
        nn.Linear(256, 4)
    )
    return net

def critic_factory():
    net = nn.Sequential(
        Feature_Extractor(n_inp=8, features=[256, 256]),
        nn.Linear(256, 1)
    )
    return net

# %%
policy = ga.core.ActorCriticPolicy(
    actor_factory_func=actor_factory,
    critic_factory_func=critic_factory,
    actor_lr = 0.00083,
    # feature_extractor_func=feature_extractor_factory,
)

# %%
agent = ga.core.A2C(
    policy=policy,
    env_factory_fn=ga.make,
    env_kwargs={"id": env_id, "max_episode_steps": max_episode_steps},
    num_envs=4,
    # n_steps=8,
    # entropy_coef=0.001,
    # gamma=0.995,
    gae_lambda=0.95,
)

# %%
agent.fit(total_timesteps=total_timesteps, save_best=True, save_dir="checkpoints/LunarLander-v2/A2C", progress_bar=tqdm)

# %%
agent.plot_scores()

# %%
max(agent.mean_scores)

# %%
import torch
import numpy as np
from stable_baselines3.common.buffers import RolloutBuffer

# %%
buffer = RolloutBuffer(buffer_size=5, observation_space=agent.envs.single_observation_space, action_space=agent.envs.single_action_space, device=agent.device, n_envs=4)

# %%
indice = np.arange(0, 20, 5)

# %%
agent.memory.observations[indice].shape

# %%
agent.memory.episode_starts.shape

# %%
for i in range(5):
    obs = agent.memory.observations[indice + i]
    actions = agent.memory.actions[indice + i].flatten()
    rewards = agent.memory.rewards[indice + i].flatten()
    eps_starts = agent.memory.episode_starts[i].flatten()
    values = torch.from_numpy(agent.memory.values[indice + i].flatten())
    log_probs = torch.from_numpy(agent.memory.log_probs[indice + i].flatten())

    buffer.add(
        obs,
        actions,
        rewards,
        eps_starts,
        values,
        log_probs
    )

# %%
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import SubprocVecEnv

# Parallel environments
vec_env = make_vec_env("LunarLander-v3", n_envs=1, vec_env_cls=SubprocVecEnv)

model = A2C("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=100000)
model.save("temp")

del model # remove to demonstrate saving and loading

model = A2C.load("temp")

obs = vec_env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")

# %%
model.rollout_buffer.observations.shape

# %%
model.policy

# %%
model = A2C.load("temp")

obs = vec_env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")

# %%
vec_env.action_space

# %%
import numpy as np

# %%
a = np.stack([[1, 2, 3], [4, 5, 6]])
a

# %%
from gym_agent.core.vec_env.subproc_vec_env import SubprocVecEnv
import gym_agent as ga

from stable_baselines3 import A2C

# %%
env = SubprocVecEnv([lambda: ga.make(id="LunarLander-v3", max_episode_steps=20, render_mode="rgb_array") for _ in range(4)])

# %%
done = False

obs, _ = env.reset()
while not done:
    obs, *_ = env.step(env.action_space.sample())

    env.render("human")

# %%
from gymnasium import Env

# %%
import numpy as np

# %%
scores = []
current_scores = np.array([1.0, 2.2, 3.0, 4.5])
dones = np.array([False, True, False, True])
rewards = np.array([0.5, 1.0, 0.2, 0.3])

# %%
current_scores += rewards
current_scores

# %%
scores.extend(current_scores[dones].tolist())

# %%
current_scores[dones] = 0.0
current_scores

# %%
scores , current_scores

# %%
eps_start = 1.0
eps_end = 0.01
eps_decay = 0.9999998

eps = eps_start

i = 0

while eps > eps_end:
    eps = eps * eps_decay
    i += 1

print(i)

# %%
(eps_end/eps_start) ** (1/time_step)

# %%
import numpy as np

# %%
a = np.ma.array([[2, 1],[0, 0],[3, 4]], mask=[[0, 0],[1,1],[0,0]], dtype=int)

# %%
np.sort(a)

# %%
a.dtype

# %%
b = {"a": 3, "b": 4}
c = {"a": None, "b": 3}

# %%
a.update(b)
a

# %%
import numpy as np

# %%
np.empty_like("3")

# %%
np.empty_like((4, 2))

# %%
import torch

# %%
m = torch.tensor([-6, 0, 3])

# %%
sigmoid_m = torch.sigmoid(m)

# %%
torch.stop_gradient(sigma_m)
